# %%
import sys
sys.path.insert(0, '/Users/boldrinicoder/lab4/FunctionClass')

import ROOT
import numpy as np
import matplotlib.pyplot as plt
import math
from array import array
import glob
from Functions import ClassFunc
import sys
sys.path.insert(0, '/Users/boldrinicoder/lab4/FunctionClass')
from Root_objects import ROOT_obj as R_o

ROOT.gROOT.SetBatch()
# Out:
# Welcome to JupyROOT 6.16/00

# %%
def Vector_creator(step1, step2, step3):
    
    angle1 = step1*2.25
    first = np.arange(0, angle1+1, 2.25)
    second = np.arange(first[-1]+0.45, first[-1]+18+0.1, 0.45)
    angle2 = second[-1]+ step2*2.25
    third = np.arange(second[-1]+2.25, angle2+1, 2.25)
    fourth = np.arange(third[-1]+0.45, third[-1]+18+0.1, 0.45)
    angle3 = fourth[-1]+step3*2.25
    fifth = np.arange(fourth[-1]+2.25, angle3, 2.25)
    
    return np.concatenate([first, second, third, fourth, fifth])

# %%
x_true = 1.16
y_true = -13.25

# %% [markdown]
# # POSITIONING 2

# %%
data_path = "/Users/boldrinicoder/lab4/data/Dense_water_2/Positioning2"

rate = array('f', np.load(data_path + '/rate_pos2.npy'))
angoli = array('f', Vector_creator(2, 120, 22))
err_angoli = array('f', [1.4]*len(rate))
err_rate = array('f', [i*5/100 for i in rate])

# %%
g = ROOT.TGraphErrors(len(rate), angoli, rate, err_angoli, err_rate)
g.GetXaxis().SetRangeUser(290,318)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()

# %%
max1 = rate.index(max(rate[0:100]))
max2 = rate.index(max(rate[100:]))
alpha = 17
beta = 303.9
psi = 142.5

x_recon = 0.18
y_recon = -13.04

# %% [markdown]
# # POSITIONING 3

# %%
data_path = "/Users/boldrinicoder/lab4/data/Dense_water_2/Positioning3"

rate = array('f', np.load(data_path + '/rate_pos3.npy'))
angoli = array('f', Vector_creator(47, 60, 37))
err_angoli = array('f', [1.4]*len(rate))
err_rate = array('f', [i*5/100 for i in rate])

# %%
g = ROOT.TGraphErrors(len(rate), angoli, rate, err_angoli, err_rate)
#g.GetXaxis().SetRangeUser(260,280)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
alpha = 121.5
beta = 272.2
psi = 187.5

x_recon = 0.18
y_recon = -13.04

# %%
max1 = rate.index(max(rate[0:100]))
max2 = rate.index(max(rate[100:]))

# %% [markdown]
# # Positioning 5

# %%
data_path = "/Users/boldrinicoder/lab4/data/Dense_water_2/Positioning5"

rate1 = array('f', np.load(data_path + '/rate_pos51.npy'))
angoli1 = array('f', np.arange(56,74.1, 0.45))
err_angoli1 = array('f', [1.4]*len(rate1))
err_rate1 = array('f', [i*5/100 for i in rate1])

g = ROOT.TGraphErrors(len(rate1), angoli1, rate1, err_angoli1, err_rate1)
#g.GetXaxis().SetRangeUser(290,318)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()

#alpha = 61
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
data_path = "/Users/boldrinicoder/lab4/data/Dense_water_2/Positioning5"

rate1 = array('f', np.load(data_path + '/rate_pos52.npy'))
angoli1 = array('f', np.arange(263.25,281.25, 0.45))
err_angoli1 = array('f', [1.4]*len(rate1))
err_rate1 = array('f', [i*5/100 for i in rate1])

g = ROOT.TGraphErrors(len(rate1), angoli1, rate1, err_angoli1, err_rate1)
#g.GetXaxis().SetRangeUser(290,318)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()

#alpha = 278.2
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
x_recon_5 = 0.67
y_recon_5 = -13.32

# %% [markdown]
# # Positioning 6

# %%
data_path = "/Users/boldrinicoder/lab4/data/Dense_water_2/Positioning6"

rate1 = array('f', np.load(data_path + '/rate_pos61.npy'))
angoli1 = array('f', np.arange(76.1,94.2, 0.45))
err_angoli1 = array('f', [1.4]*len(rate1))
err_rate1 = array('f', [i*5/100 for i in rate1])

g = ROOT.TGraphErrors(len(rate1), angoli1, rate1, err_angoli1, err_rate1)
#g.GetXaxis().SetRangeUser(290,318)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()

#alpha = 65.2
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
rate1 = array('f', np.load(data_path + '/rate_pos62.npy'))
angoli1 = array('f', np.arange(256.1,274.2, 0.45))
err_angoli1 = array('f', [1.4]*len(rate1))
err_rate1 = array('f', [i*5/100 for i in rate1])

g = ROOT.TGraphErrors(len(rate1), angoli1, rate1, err_angoli1, err_rate1)
#g.GetXaxis().SetRangeUser(290,318)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()

#alpha = 272.8
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
x_recon_6 = 0.67
y_recon_6 = -13.32

# %% [markdown]
# # Positioning 1

# %%
data_path = "/Users/boldrinicoder/lab4/data/Dense_water_2/Positioning1"

rate1 = array('f', np.load(data_path + '/dense_rate_rel_pos11.npy'))
angoli1 = array('f', np.arange(36,52.1, 0.4))
err_angoli1 = array('f', [1.4]*len(rate1))
err_rate1 = array('f', [i*5/100 for i in rate1])

g = ROOT.TGraphErrors(len(rate1), angoli1, rate1, err_angoli1, err_rate1)
#g.GetXaxis().SetRangeUser(290,318)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()

#alpha = 45
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
rate1 = array('f', np.load(data_path + '/dense_rate_rel_pos11.npy'))
angoli1 = array('f', np.arange(278.9,294.91, 0.4))
err_angoli1 = array('f', [1.4]*len(rate1))
err_rate1 = array('f', [i*5/100 for i in rate1])

g = ROOT.TGraphErrors(len(rate1), angoli1, rate1, err_angoli1, err_rate1)
#g.GetXaxis().SetRangeUser(290,318)
c = ROOT.TCanvas("c", "c", 1000,1000, 1000,800)
g.Draw("AP")
c.Draw()

#alpha = 286.5
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %% [markdown]
# # Reconstruction all intercepts

# %%
import numpy as np
import ROOT
import math as mt
import matplotlib.pyplot as plt
import re

# %%
def Line_rotation(m_lor, q_lor, r, angles = None):
    
    coeff = []
    #rotated line from ste formula
    for ang in angles:
        
        m_rot = (m_lor*mt.cos(ang)-mt.sin(ang))/(mt.cos(ang)+m_lor*mt.sin(ang))
        q_rot = (m_lor*r)/(mt.cos(ang)+m_lor*mt.sin(ang))
        coeff.append([m_rot,q_rot])

    return coeff[0], coeff[1]

def ellipse_confidence(x,y, t):
    
    #http://www.visiondummy.com/2014/04/draw-error-ellipse-representing-covariance-matrix/
    
    #calcola la media
    center_x = x.mean()
    center_y = y.mean()
    #calcolo deviazioni
    s_x = np.std(x)
    s_y = np.std(y)
    #covariance matrix
    cov = np.cov(x,y)
    eigenvalues, eigv = np.linalg.eig(cov)
    
    #maj_axis = 2*np.sqrt(2.35*max(eigenvalues))
    #min_axis = 2*np.sqrt(2.35*min(eigenvalues))
    maj_axis = np.sqrt(t*max(eigenvalues))
    min_axis = np.sqrt(t*min(eigenvalues))
    
    i = np.where(eigenvalues==max(eigenvalues))
    max_eigenvector = eigv[:,i]
    
    theta = mt.atan(max_eigenvector[1][0][0]/max_eigenvector[0][0][0])
    
    return [center_x, center_y], maj_axis, min_axis, theta

# %%
#computing lor #MAIN
alphas = np.radians([16.2, 61.0, 45.0])
betas = np.radians([303.75, 278.2, 286.5])
psi_vec = np.radians([142.5, 165.0, 157.5])

rotated_lines = []

for al,be, ps in zip(alphas, betas, psi_vec):
    
    r = 0.32645
    cotan = 1 / mt.tan(ps/2)
    q = -0.32645*cotan
    m = mt.sin(ps)/(mt.cos(ps)-1)
    coeff1, coeff2 = Line_rotation(m, q,r, angles = [al, be])
    rotated_lines.append(coeff1)
    rotated_lines.append(coeff2)

draw_points = []
already_done = []
for co in rotated_lines:
    already_done.append(co)
    m = co[0]
    q = co[1]
    other_lines = [x for x in rotated_lines if x != co and x not in already_done]
    
    for ot_co in other_lines:
        m1 = ot_co[0]
        q1 = ot_co[1]
        
        x_int = (q1-q)/(m-m1)
        y_int = m*x_int+q
        print(x_int*100, y_int*100)
        draw_points.append([x_int*100, y_int*100])

x = [i[0] for i in draw_points]
y = [i[1] for i in draw_points]

x_avg = np.mean(x)
y_avg = np.mean(y)

x_std = np.std(x)
y_std = np.std(y)

x1 = np.array([x_avg, y_avg])

print(x_avg, '+-', np.std(x), y_avg, '+-', np.std(y))
# Out:
# 0.2894370723738464 -13.004537442607772
# 0.6392303205860952 -13.2490106750351
# 0.6917192312311348 -13.28569558452825
# 1.6783897335902405 -13.975287302736774
# 0.3369200765021415 -13.037723684949306
# 0.4840933186291403 -12.855172451477406
# 0.9031097598658739 -12.533649827709562
# 0.7788353093142442 -12.629008967534084
# 0.39834911007704976 -12.920966296762321
# 0.6758790383796075 -13.342048865340395
# -0.15626087106359468 -11.229538635334121
# 0.4622028591207088 -12.799600282511204
# 0.8474435936368901 -12.731688521217949
# 1.2483730636377481 -11.305336505141096
# 0.6519024934073515 -12.43904058377647
# 0.6619749406192319 +- 0.4114902901097403 -12.755887041777452 +- 0.6896844782817388

# %%
"""
fig = plt.figure(figsize=(20,10))
plt.scatter(xs, ys, c = 'blue', s= 5)
plt.scatter(x_avg, y_avg, c = 'red', s = 20)
fig.savefig("./prova4.png")
"""

c = ROOT.TCanvas("c", "c", 1000,1000,2000,1200)
legend = ROOT.TLegend(0.15,0.71,0.35,0.89)
legend.SetHeader("", "C")
legend.SetLineWidth(0)

g = ROOT.TGraph(len(x), np.array(x), np.array(y))
g.SetTitle('Second method')
g.GetXaxis().SetLimits(-50,18)
g.GetYaxis().SetRangeUser(-20,20)
g.SetMarkerSize(1)
g.SetMarkerStyle(ROOT.kStar)
g.GetXaxis().SetTitle("x coordinate [cm]")
g.GetYaxis().SetTitle("y coordinate [cm]")
g.GetYaxis().SetTitleOffset(0.8)

g_sub = ROOT.TGraph(len(x), np.array(x), np.array(y))
g_sub.SetTitle('')
g_sub.GetXaxis().SetLimits(-1.9,2.9)
g_sub.GetYaxis().SetRangeUser(-16,-9.5)
g_sub.SetMarkerSize(1)
g_sub.SetMarkerStyle(ROOT.kStar)


l1 = ROOT.TLine(-17.5,0,17.5,0)
l2 = ROOT.TLine(0,-17.5,0,17.5)


circle = ROOT.TEllipse(0,0,17.5,17.5)
circle.SetLineColor(1)
circle.SetLineWidth(3)
circle.SetFillStyle(0)

sub_circle = ROOT.TEllipse(0,0,17.5,17.5)
sub_circle.SetLineColor(1)
sub_circle.SetLineWidth(3)
sub_circle.SetFillStyle(0)

real_slit = ROOT.TEllipse(0,0,13.3,13.3)
real_slit.SetLineColor(1)
real_slit.SetLineWidth(1)
real_slit.SetFillStyle(0)
real_slit.SetLineStyle(9)

#confidence levels 68
[center_x, center_y], maj_axis, min_axis, theta = ellipse_confidence(np.array(x), np.array(y), 2.35)

cl = ROOT.TEllipse(center_x,center_y,min_axis,maj_axis,0,360, theta)
cl.SetLineColor(0)
cl.SetFillColorAlpha(ROOT.kBlue, 0.2)
cl.SetFillStyle(1100)
legend.AddEntry(cl,"68% ellipse.","f")

#confidence levels 95
[center_x, center_y], maj_axis1, min_axis1, theta1 = ellipse_confidence(np.array(x), np.array(y), 5.991)

cl1 = ROOT.TEllipse(center_x,center_y,min_axis1,maj_axis1,0,360, theta1)
cl1.SetLineColor(0)
cl1.SetFillColorAlpha(ROOT.kGreen, 0.2)
cl1.SetFillStyle(1100)
legend.AddEntry(cl1,"95% ellipse","f")

t1 = ROOT.TLatex(.8,-10.3,"68% ellipse")
t1.SetTextAngle(-45)
t1.SetTextSize(.035)

t2 = ROOT.TLatex(1,-9.5,"95% ellipse")
t2.SetTextAngle(-45)
t2.SetTextSize(.035)

t3 = ROOT.TLatex(-8.6,11,"4th slit")
t3.SetTextSize(.025)
t3.SetTextAngle(28)

zoom_box = ROOT.TBox(-1.9,-16,2.9,-9)
zoom_box.SetLineColor(1)
zoom_box.SetLineWidth(1)
zoom_box.SetFillStyle(0)
zoom_box.SetLineStyle(1)

zoom_sigma = ROOT.TBox(x_avg-x_std,y_avg-y_std,x_avg+x_std,y_avg+y_std)
zoom_sigma.SetLineColor(0)
zoom_sigma.SetFillColorAlpha(ROOT.kBlue, 0.2)
zoom_sigma.SetFillStyle(1100)
#legend.AddEntry(zoom_sigma,"1#sigma region","f")

zoom_2sigma = ROOT.TBox(x_avg-2*x_std,y_avg-2*y_std,x_avg+2*x_std,y_avg+2*y_std)
zoom_2sigma.SetLineColor(0)
zoom_2sigma.SetFillColorAlpha(ROOT.kGreen, 0.2)
zoom_2sigma.SetFillStyle(1100)
#legend.AddEntry(zoom_2sigma,"2#sigma region","f")




legend.AddEntry(g,"Measure","P");


m = ROOT.TMarker(x_avg, y_avg, 20)
m.SetMarkerSize(1)
m.SetMarkerColor(ROOT.kRed)
legend.AddEntry(m,"Method true position","P")

"""
m1 = ROOT.TMarker(x_true, y_true, 20)
m1.SetMarkerSize(2)
m1.SetMarkerStyle(34)
m1.SetMarkerColor(ROOT.kRed)
legend.AddEntry(m1,"Measured true position","P")
"""
g_real = ROOT.TGraphErrors(1, np.array(x_true), np.array(y_true), np.array(0.1), np.array(0.1))
g_real.SetTitle('')
g_real.SetLineWidth(2)
g_real.GetXaxis().SetLimits(-1.9,2.9)
g_real.GetYaxis().SetRangeUser(-17,-8)
g_real.SetMarkerSize(1)
g_real.SetMarkerStyle(21)
g_real.SetMarkerColor(ROOT.kRed)
g_real.SetLineColor(ROOT.kRed)
legend.AddEntry(g_real,"Method 2 reconstructed position","Pel")

#drawing
g.Draw('AP')
l1.Draw()
l2.Draw()
circle.Draw()
real_slit.Draw()
m.Draw()
#m1.Draw()
g_real.Draw("P")
zoom_box.Draw()
t3.Draw()
legend.Draw()


subpad = ROOT.TPad("subpad","",0.12,0.12,0.425,0.7)
subpad.Draw()
subpad.cd()
g_sub.Draw('AP')
real_slit.Draw()
#sub_circle.Draw()
cl.Draw()
cl1.Draw()
#zoom_sigma.Draw()
#zoom_2sigma.Draw()
m.Draw()
g_real.Draw("P")
#t1.Draw()
#t2.Draw()



c.cd()
c.Draw()
c.SaveAs("./Water_all_inter.png", "png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./Water_all_inter.png has been created

# %% [markdown]
# # Reconstruction paired

# %%
f = open('./positions_bianca.txt', 'r')
lines = f.readlines()
x = []
y = []

for line in lines:
    line = re.split(',|:', line)
    x_pos_ind = line.index(list(l for l in line if 'x' in l)[0])+1
    x_pos = float(line[x_pos_ind])
    x.append(x_pos)
    y_pos_ind = line.index(list(l for l in line if 'y' in l)[0])+1
    y_pos= float(line[y_pos_ind])
    y.append(y_pos)

average_x = np.mean(x)
average_y = np.mean(y)
std_dev_x = np.std(x)
std_dev_y = np.std(y)

print('Best pos {}+-{}, {}+-{}'.format(average_x, std_dev_x/mt.sqrt(len(x)), average_y, std_dev_y/mt.sqrt(len(x))))

print('x:', x)
print('y:', y)

x2 = np.array([average_x, average_y])
# Out:
# Best pos 0.5383297748061698+-0.10192925600921167, -12.91072075019373+-0.21479389242703195
# x: [0.28903809341054926, 0.6749473625723761, 0.6510038684355842]
# y: [-12.986611138888444, -13.323657313833568, -12.421893797859179]

# %%
c = ROOT.TCanvas("c", "c", 1000,1000,2000,1200)
legend = ROOT.TLegend(0.15,0.71,0.35,0.89)
legend.SetHeader("", "C")
legend.SetLineWidth(0)

g = ROOT.TGraph(len(x), np.array(x), np.array(y))
g.SetTitle('First method')
g.GetXaxis().SetLimits(-50,18)
g.GetYaxis().SetRangeUser(-20,20)
g.SetMarkerSize(1)
g.SetMarkerStyle(ROOT.kStar)
g.GetXaxis().SetTitle("x coordinate [cm]")
g.GetYaxis().SetTitle("y coordinate [cm]")
g.GetYaxis().SetTitleOffset(0.8)

g_sub = ROOT.TGraph(len(x), np.array(x), np.array(y))
g_sub.SetTitle('')
g_sub.GetXaxis().SetLimits(-0.5,1.5)
g_sub.GetYaxis().SetRangeUser(-15,-11)
g_sub.SetMarkerSize(1)
g_sub.SetMarkerStyle(ROOT.kStar)


l1 = ROOT.TLine(-17.5,0,17.5,0)
l2 = ROOT.TLine(0,-17.5,0,17.5)


circle = ROOT.TEllipse(0,0,17.5,17.5)
circle.SetLineColor(1)
circle.SetLineWidth(3)
circle.SetFillStyle(0)

sub_circle = ROOT.TEllipse(0,0,17.5,17.5)
sub_circle.SetLineColor(1)
sub_circle.SetLineWidth(3)
sub_circle.SetFillStyle(0)

real_slit = ROOT.TEllipse(0,0,13.3,13.3)
real_slit.SetLineColor(1)
real_slit.SetLineWidth(1)
real_slit.SetFillStyle(0)
real_slit.SetLineStyle(9)

#confidence levels
[center_x, center_y], maj_axis, min_axis, theta = ellipse_confidence(np.array(x), np.array(y), 2.35)

cl = ROOT.TEllipse(center_x,center_y,min_axis,maj_axis,0,360, theta)
cl.SetLineColor(0)
cl.SetFillColorAlpha(ROOT.kBlue, 0.2)
cl.SetFillStyle(1100)
legend.AddEntry(cl,"68% C.L.","f")

[center_x, center_y], maj_axis1, min_axis1, theta1 = ellipse_confidence(np.array(x), np.array(y), 5.991)

cl1 = ROOT.TEllipse(center_x,center_y,min_axis1,maj_axis1,0,360, theta1)
cl1.SetLineColor(0)
cl1.SetFillColorAlpha(ROOT.kGreen, 0.2)
cl1.SetFillStyle(1100)
legend.AddEntry(cl1,"95% C.L.","f")

t1 = ROOT.TLatex(.8,-11,"68% ellipse")
t1.SetTextAngle(-45)
t1.SetTextSize(.035)

t2 = ROOT.TLatex(1,-10.5,"95% ellipse")
t2.SetTextAngle(-45)
t2.SetTextSize(.035)

t3 = ROOT.TLatex(-8.6,11,"4th slit")
t3.SetTextSize(.025)
t3.SetTextAngle(28)

zoom_box = ROOT.TBox(-0.8,-16,2.2,-11)
zoom_box.SetLineColor(1)
zoom_box.SetLineWidth(1)
zoom_box.SetFillStyle(0)
zoom_box.SetLineStyle(1)

zoom_sigma = ROOT.TBox(average_x-std_dev_x,average_y-std_dev_y,average_x+std_dev_x,average_y+std_dev_y)
zoom_sigma.SetLineColor(0)
zoom_sigma.SetFillColorAlpha(ROOT.kBlue, 0.2)
zoom_sigma.SetFillStyle(1100)
#legend.AddEntry(zoom_sigma,"1#sigma region","f")

zoom_2sigma = ROOT.TBox(average_x-2*std_dev_x,average_y-2*std_dev_y,average_x+2*std_dev_x,average_y+2*std_dev_y)
zoom_2sigma.SetLineColor(0)
zoom_2sigma.SetFillColorAlpha(ROOT.kGreen, 0.2)
zoom_2sigma.SetFillStyle(1100)
#legend.AddEntry(zoom_2sigma,"2#sigma region","f")




legend.AddEntry(g,"All measures","P");


m = ROOT.TMarker(average_x, average_y, 20)
m.SetMarkerSize(1)
m.SetMarkerColor(ROOT.kRed)
legend.AddEntry(m,"Method 1 reconstructed position","P")

g_real = ROOT.TGraphErrors(1, np.array(x_true), np.array(y_true), np.array(0.1), np.array(0.1))
g_real.SetTitle('')
g_real.SetLineWidth(2)
g_real.GetXaxis().SetLimits(-1.9,2.9)
g_real.GetYaxis().SetRangeUser(-17,-8)
g_real.SetMarkerSize(1)
g_real.SetMarkerStyle(21)
g_real.SetMarkerColor(ROOT.kRed)
g_real.SetLineColor(ROOT.kRed)
legend.AddEntry(g_real,"Measured true position","Pel")


#drawing
g.Draw('AP')
l1.Draw()
l2.Draw()
circle.Draw()
real_slit.Draw()
m.Draw()
zoom_box.Draw()
t3.Draw()
legend.Draw()
g_real.Draw("P")


subpad = ROOT.TPad("subpad","",0.17,0.14,0.39,0.6)
subpad.Draw()
subpad.cd()
g_sub.Draw('AP')
real_slit.Draw()
sub_circle.Draw()
#zoom_sigma.Draw()
#zoom_2sigma.Draw()
cl.Draw()
cl1.Draw()
m.Draw()
g_real.Draw("P")
#t1.Draw()
#t2.Draw()



c.cd()
c.Draw()
c.SaveAs("./Water_paired.png", "png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ./Water_paired.png has been created

# %% [markdown]
# # Hotelling

# %%
import numpy as np
import ROOT
import math as mt
import matplotlib.pyplot as plt
from numpy.linalg import inv
from scipy.stats import f
import scipy

# %%
alphas = np.radians([16.2, 61.0, 45.0])
betas = np.radians([303.75, 278.2, 286.5])
psi_vec = np.radians([142.5, 165.0, 157.5])

x_true = 1.16
y_true = -13.25
rotated_lines = []

for al,be, ps in zip(alphas, betas, psi_vec):
    
    r = 0.32645
    cotan = 1 / mt.tan(ps/2)
    q = -0.32645*cotan
    m = mt.sin(ps)/(mt.cos(ps)-1)
    coeff1, coeff2 = Line_rotation(m, q,r, angles = [al, be])
    rotated_lines.append(coeff1)
    rotated_lines.append(coeff2)

draw_points = []
already_done = []
for co in rotated_lines:
    already_done.append(co)
    m = co[0]
    q = co[1]
    other_lines = [x for x in rotated_lines if x != co and x not in already_done]
    
    for ot_co in other_lines:
        m1 = ot_co[0]
        q1 = ot_co[1]
        
        x_int = (q1-q)/(m-m1)
        y_int = m*x_int+q
        draw_points.append([x_int*100, y_int*100])

x = [i[0] for i in draw_points]
y = [i[1] for i in draw_points]

# %%
x_cov = np.array([[i[0], i[1]] for i in draw_points]).T

x_avg = np.mean(x)
y_avg = np.mean(y)

x_std = np.std(x)
y_std = np.std(y)

print(x_avg, x_std/mt.sqrt(len(x)), y_avg, y_std/mt.sqrt(len(y)))
x1 = np.array([x_avg, y_avg])
x_real = np.array([x_true, y_true])

x_t = x1-x_real

#now we implement hotelling for two sample statistics:
#POOLED COVARIANCE MATRIX
n1 = len(x)
n2 = 1
p = 2
cov_1 = np.cov(x_cov, rowvar = True)
cov_2 = np.array([[.04,0],[0,.04]])

b = x_t.T
#cov_pooling = ((n1-1)*cov_1+(n2-1)*cov_2)/(n1+n2-2)
cov_pooling = cov_1/15 + cov_2
Sinv = inv(cov_pooling)


t = (b.dot(Sinv.dot(x_t)))

#defining Fischer F
F = (n1+n2-p-1)/((n1+n2-2)*p)*t

v1=p
v2=(n1+n2-p-1)
P=1-f.cdf(F,v1,v2)

a = 0.05
if P>= 0.05:
    print('Mean vectors result not significant.')
else:
    print('Mean vectors result significant.')
# Out:
# 0.6619749406192319 0.10624633604807218 -12.755887041777452 0.17807576656819502
# Mean vectors result not significant.

# %%
t, F, P
# Out:
# (7.330661091899066, 3.403521221238852, 0.06475960345868814)

# %%
#NOW WE DO THE SAME WITH THE VALUES FROM THE PAIRED LINES METHOD:
x_paired = [0.28903809341054926, 0.6749473625723761, 0.6510038684355842]
y_paired = [-12.986611138888444, -13.323657313833568, -12.421893797859179]

x_paired_joined = []
for i, j in zip(x_paired, y_paired):
    x_paired_joined.append([i,j])

x2 = np.array([np.mean(x_paired), np.mean(y_paired)])

x_t = x2-x_real

#now we implement hotelling for two sample statistics:
#POOLED COVARIANCE MATRIX
n1 = len(x_paired)
n2 = 1
p = 2
cov_1 = np.cov(np.array(x_paired_joined).T, rowvar = True)
cov_2 = np.array([[.04,0],[0,.04]])

b = x_t.T

#pooling covariance matrix
cov_pooling = ((n1-1)*cov_1+(n2-1)*cov_2)/(n1+n2-2)
Sinv = inv(cov_pooling)


t = ((n1*n2)/(n1+n2))*(b.dot(Sinv.dot(x_t)))

#defining Fischer F
F = (n1+n2-p-1)/((n1+n2-2)*p)*t

v1=p
v2=(n1+n2-p-1)
P=1-f.cdf(F,v1,v2)

# %%
t, F, P
# Out:
# (6.9574844318555416, 1.7393711079638854, 0.4725219274529806)

# %% [markdown]
# # Confronto

# %%
#NOW PLOTTING WITH RESPECT TO THE CENTER FOR BOTH ESTIMATION. PROPAGATION OF ERROR IS DONE THROUGH
#THE SUM OF THE COVARIANCE MATRICES OF THE MEASURED REAL AND THE RECONSTRUCTED ONE.
#WE KNOW THE REAL VALUE IS IN 0,0 DIFFERENCE.
x_true = 1.16
y_true = -13.25

legend = ROOT.TLegend(0.15,0.7,0.5,0.89)
legend.SetHeader("", "C")
legend.SetLineWidth(0)

x_t1 = x1-x_real
x_t2 = x2-x_real

cov_1 = np.cov(x_cov, rowvar = True)/15
cov_2 = np.cov(np.array(x_paired_joined).T, rowvar = True)/3
cov_real = np.array([[0.04,0], [0,0.04]])

#fist ellipse

cov_sum_1 = cov_1 + cov_real
eigenvalues1, eigv1 = np.linalg.eig(cov_sum_1)
maj_axis1 = np.sqrt(2.35*max(eigenvalues1))
min_axis1 = np.sqrt(2.35*min(eigenvalues1))
i1 = np.where(eigenvalues1==max(eigenvalues1))
max_eigenvector1 = eigv1[:,i1]
theta1 = mt.atan(max_eigenvector1[1][0][0]/max_eigenvector1[0][0][0])

el1 = ROOT.TEllipse(x_t1[0],x_t1[1],min_axis1,maj_axis1,0,360, theta1)
el1.SetLineColor(0)
el1.SetFillColorAlpha(ROOT.kGreen, 0.2)
el1.SetFillStyle(1100)
legend.AddEntry(el1, "Pooled covariance matrix all intercepts", "f")

#second ellipse

cov_sum_2 = cov_2 + cov_real
eigenvalues2, eigv2 = np.linalg.eig(cov_sum_2)
maj_axis2 = np.sqrt(2.35*max(eigenvalues2))
min_axis2 = np.sqrt(2.35*min(eigenvalues2))
i2 = np.where(eigenvalues2==max(eigenvalues2))
max_eigenvector2 = eigv1[:,i2]
theta2 = mt.atan(max_eigenvector2[1][0][0]/max_eigenvector2[0][0][0])

el2 = ROOT.TEllipse(x_t2[0],x_t2[1],min_axis2,maj_axis2,0,360, theta2)
el2.SetLineColor(0)
el2.SetFillColorAlpha(ROOT.kRed, 0.2)
el2.SetFillStyle(1100)
legend.AddEntry(el2, "Pooled covariance matrix paired", "f")

g = ROOT.TGraph(1, np.array(0), np.array(0))
g.SetTitle('')
g.GetXaxis().SetLimits(-1.3,.2)
g.GetXaxis().SetTitle('x coordinate [cm]')
g.GetYaxis().SetRangeUser(-1.2,2)
g.GetYaxis().SetTitle('y coordinate [cm]')
g.GetYaxis().SetTitleOffset(1.2)
g.SetMarkerSize(1.5)
g.SetMarkerStyle(20)
g.GetYaxis().SetLabelOffset(0.02)
legend.AddEntry(g,"Expected value", "p")

g1 = ROOT.TGraph(1, np.array(x_t1[0]), np.array(x_t1[1]))
g1.SetTitle('')
g1.GetXaxis().SetLimits(-2,1)
g1.GetXaxis().SetTitle('X[cm]')
g1.GetYaxis().SetRangeUser(-2,2.3)
g1.GetYaxis().SetTitle('y coordinate [cm]')
g1.SetMarkerSize(1.5)
g1.SetMarkerStyle(21)
legend.AddEntry(g1,"All intercepts", "p")

g2 = ROOT.TGraph(1, np.array(x_t2[0]), np.array(x_t2[1]))
g2.SetTitle('')
g2.GetXaxis().SetLimits(-2,1)
g2.GetXaxis().SetTitle('X[cm]')
g2.GetYaxis().SetRangeUser(-2,2.3)
g2.GetYaxis().SetTitle('Y[cm]')
g2.SetMarkerSize(1.5)
g2.SetMarkerStyle(22)
legend.AddEntry(g2,"Paired", "p")

line1 = ROOT.TLine(0,-1.2,0,2)
line1.SetLineStyle(2)

line2 = ROOT.TLine(-1.3,0,.2,0)
line2.SetLineStyle(2)

g.Draw("AP")
g1.Draw("same P")
g2.Draw("same P")
el1.Draw()
el2.Draw()
line1.Draw()
line2.Draw()
legend.Draw()

c.Draw()
c.SaveAs('./difference_real_Water.root', 'root')
c.SaveAs('./difference_real_Water.png', 'png')
# Out:
# Info in <TCanvas::SaveAs>: ROOT file ./difference_real_Water.root has been created
# Info in <TCanvas::Print>: png file ./difference_real_Water.png has been created
