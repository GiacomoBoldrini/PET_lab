# %%
"""
This program reads spectrum iteration and plots bias vs full width half maximum 
"""

import ROOT as r
import numpy as np
import matplotlib.pyplot as plt
import math

#creates a directory
def mkdir_p(mypath):

    from errno import EEXIST
    from os import makedirs,path

    try:
        makedirs(mypath)
    except OSError as exc: 
        if exc.errno == EEXIST and path.isdir(mypath):
            pass
        else: raise
            
def FWHM(function):
    #Annullo il fondo
    function.SetParameter(3,0)
    function.SetParameter(4,0)
    function.SetParameter(5,0)
    mean = function.GetParameter(1)

    maxi = function.GetMaximum()
    Xmax = function.GetMaximumX()
    temp = Xmax
    estremo_sx = 0
    estremo_dx = 0
    epsilon = 0.0001

    #Determino l'estremo sinistro
    while(1):
        if function.Eval(temp) < maxi/2:
            estremo_sx = temp
            break

        temp -= epsilon

    temp = Xmax

    #Determino l'estremo destro
    while(1):
        if function.Eval(temp) < maxi/2:
            estremo_dx = temp
            break
        temp += epsilon
    return (estremo_dx - estremo_sx)
            
#Function which compute the percentage resolution as FWHM/mean*100
def Resolution(function):
    
    #Annullo il fondo
    function.SetParameter(3,0)
    function.SetParameter(4,0)
    mean = function.GetParameter(1)

    maxi = function.GetMaximum()
    Xmax = function.GetMaximumX()
    temp = Xmax
    estremo_sx = 0
    estremo_dx = 0
    epsilon = 0.0001

    #Determino l'estremo sinistro
    while(1):
        if function.Eval(temp) < maxi/2:
            estremo_sx = temp
            break

        temp -= epsilon

    temp = Xmax

    #Determino l'estremo destro
    while(1):
        if function.Eval(temp) < maxi/2:
            estremo_dx = temp
            break
        temp += epsilon

    return (estremo_dx - estremo_sx)*100/mean

def Res_Error(function, fwhm):
    mean = function.GetParameter(1)
    err_mean = function.GetParError(1)
    err_sigma = function.GetParError(2)
    err_fwhm = 2.355*err_sigma
    
    return 100*math.sqrt(((1/mean)**2)*err_fwhm**2+((fwhm/mean**2)**2)*err_mean**2)

def Plotter(f):
    f = open(f, "r")
    lists = f.readlines()
    value = []
    for i in lists:
        value.append(i.strip())
    value = list(map(int,value))
    n = np.arange(0,1002,1)
    plt.plot(n,value)

data = str(181128)

# %%
"""f = open("/home/giacomo/lab/0.txt", "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))
n = np.arange(0,1002,1)
print(n)
plt.plot(n,value)
"""
# Out:
# 'f = open("/home/giacomo/lab/0.txt", "r")\nlists = f.readlines()\nvalue = []\nfor i in lists:\n    value.append(i.strip())\nvalue = list(map(int,value))\nn = np.arange(0,1002,1)\nprint(n)\nplt.plot(n,value)\n'

# %%
OOS_Resolutions = []
OOS_Errors = []

# %% [markdown]
# # Left Scintillator (0)

# %% [markdown]
#  First spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}20.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))

#Plotter("/home/giacomo/lab/data/{}/{}01.txt".format(data,data))

#set this manually
sup = 110
inf = 70
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,110,18,300,200,110)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 92
# integral 146802
#  FCN=53524.3 FROM MIGRAD    STATUS=CONVERGED    1064 CALLS        1065 TOTAL
#                      EDM=0.000229213    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   4.4 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -2.07414e+07   9.87999e+05  -0.00000e+00   8.53585e-06
#    2  p1           4.76154e+02   1.03435e+01   0.00000e+00   6.23030e+00
#    3  p2           1.49753e+02   4.14002e+00   0.00000e+00  -1.54566e+01
#    4  p3           9.54542e+02   2.69777e+01   0.00000e+00   4.35736e-01
#    5  p4          -5.34332e+04   8.45299e+02  -0.00000e+00   4.51798e-03
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

#
-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.924567944004058 pm 0.03288955239490434

# %% [markdown]
# # 7 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}26.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 400
inf = 300
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameter(0,2200)
fit.SetParameter(1,830)
fit.SetParameter(2,18)
fit.SetParameter(5,80)
#fit.SetParameters(2200,830,18,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 347
# integral 135040
#  FCN=196.461 FROM MIGRAD    STATUS=CONVERGED     339 CALLS         340 TOTAL
#                      EDM=8.268e-10    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.8 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.90901e+03   1.51954e+01   6.67476e-03  -1.37534e-06
#    2  p1           3.48740e+02   4.19742e-02  -3.95079e-06  -1.25673e-04
#    3  p2           1.64562e+01   5.30068e-02  -1.52000e-05  -2.59681e-04
#    4  p3          -2.30620e+00   5.93425e-02   5.50966e-06   5.50208e-04
#    5  p4           1.01456e+03   2.22233e+01   2.55960e-03  -1.69543e-07
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.857263642821662 pm 0.03580738323600622

# %% [markdown]
# # 8 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}27.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 490
inf = 280
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,400,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 392
# integral 161086
#  FCN=351.65 FROM MIGRAD    STATUS=CONVERGED     434 CALLS         435 TOTAL
#                      EDM=7.04252e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.58376e+03   1.37419e+01   1.42622e-01  -4.16920e-07
#    2  p1           3.92206e+02   4.39317e-02   5.64798e-04  -4.37025e-04
#    3  p2           1.85279e+01   5.20047e-02   5.17737e-04   1.86056e-04
#    4  p3          -1.22853e+00   1.54269e-02   3.22631e-05  -2.61092e-02
#    5  p4           6.77826e+02   6.56171e+00   1.36195e-02  -5.40588e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.866026145009265 pm 0.031238652428604616

# %% [markdown]
# # 9 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}28.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 600
inf = 420
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,500,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 501
# integral 143939
#  FCN=265.881 FROM MIGRAD    STATUS=CONVERGED     404 CALLS         405 TOTAL
#                      EDM=2.80915e-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.6 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.81414e+03   1.08213e+01  -1.31602e-02  -3.61644e-06
#    2  p1           4.99827e+02   5.67143e-02  -4.17885e-05  -4.90842e-04
#    3  p2           2.34607e+01   7.05718e-02   4.05816e-05   2.46659e-04
#    4  p3          -8.53286e-01   1.97441e-02  -3.92317e-05   2.02117e-02
#    5  p4           5.83624e+02   1.09097e+01   2.30446e-02   3.73904e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.8156651450482455 pm 0.03326265318890095

# %% [markdown]
# # 10 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}29.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 700
inf = 450
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,500,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 562
# integral 144488
#  FCN=335.203 FROM MIGRAD    STATUS=CONVERGED     415 CALLS         416 TOTAL
#                      EDM=2.76013e-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.4 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.41857e+03   9.41929e+00  -5.24529e-03  -1.95961e-06
#    2  p1           5.60572e+02   6.41441e-02  -1.62935e-05   1.29449e-04
#    3  p2           2.64325e+01   7.76745e-02   5.55244e-05  -6.80833e-04
#    4  p3          -5.42462e-01   1.01294e-02  -5.75689e-07  -4.65796e-02
#    5  p4           4.35927e+02   6.37142e+00   1.22405e-03  -8.03275e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.851481312086195 pm 0.03264392781252991

# %% [markdown]
# # 11 spectrum

# %%
data = str(181130)



f = open("/home/giacomo/lab/data/{}/{}01.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 750
inf = 500
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,650,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 609
# integral 140726
#  FCN=327.245 FROM MIGRAD    STATUS=CONVERGED     442 CALLS         443 TOTAL
#                      EDM=2.87156e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.18838e+03   8.66242e+00   8.66200e-02   9.35623e-07
#    2  p1           6.09243e+02   7.09052e-02   8.71574e-04   1.93861e-04
#    3  p2           2.86729e+01   8.71160e-02   8.02830e-04  -3.21716e-04
#    4  p3          -5.31839e-01   1.01471e-02   1.42919e-05   2.43520e-02
#    5  p4           4.49729e+02   6.92999e+00   9.62606e-03   3.63864e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.836547770312591 pm 0.03368663041478023

# %% [markdown]
# # 12 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}02.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 800
inf = 550
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,670,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 669
# integral 131511
#  FCN=272.902 FROM MIGRAD    STATUS=CONVERGED     387 CALLS         388 TOTAL
#                      EDM=1.51618e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.90785e+03   7.69678e+00  -3.31755e-03  -1.25042e-05
#    2  p1           6.65578e+02   7.87097e-02  -5.17861e-05   1.20744e-03
#    3  p2           3.12265e+01   9.70608e-02  -1.13228e-04  -7.31546e-04
#    4  p3          -4.57199e-01   9.40506e-03  -1.19526e-05  -8.45378e-02
#    5  p4           4.11598e+02   6.85639e+00   7.93375e-03  -1.34721e-04
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.812129329268235 pm 0.03435525113621333

# %% [markdown]
# # 13 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}03.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 880
inf = 600
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,710,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 720
# integral 130683
#  FCN=286.513 FROM MIGRAD    STATUS=CONVERGED     396 CALLS         397 TOTAL
#                      EDM=7.26658e-10    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   3.1 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.74254e+03   7.10717e+00   2.29339e-02  -3.73828e-06
#    2  p1           7.21380e+02   8.64513e-02  -2.37728e-05   2.05094e-04
#    3  p2           3.37385e+01   1.06657e-01  -9.52393e-05  -8.02970e-05
#    4  p3          -3.85078e-01   7.95074e-03   2.33125e-05   1.63537e-02
#    5  p4           3.79132e+02   6.41988e+00  -1.80675e-02   1.68067e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.787632177444091 pm 0.03483138661858479

# %% [markdown]
# # 14 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}04.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 920
inf = 650
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,770,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 782
# integral 129534
#  FCN=270.822 FROM MIGRAD    STATUS=CONVERGED     513 CALLS         514 TOTAL
#                      EDM=9.27732e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.61354e+03   6.57491e+00   5.98511e-02   1.77277e-05
#    2  p1           7.78500e+02   9.42035e-02   1.04492e-03   1.64923e-03
#    3  p2           3.66778e+01   1.16692e-01   9.61785e-04   2.64564e-03
#    4  p3          -3.63046e-01   7.99221e-03   9.56215e-06   5.19679e-02
#    5  p4           3.75870e+02   6.75847e+00   7.97032e-03   4.77189e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.844902695639555 pm 0.03531277523458555

# %%
#Gain = [5,6,9,12,15,18,21,24,28,32]
Gain= [9,12,15,18,21,24,28,32,36,40,44,48]
print(OOS_Resolutions)
print(OOS_Errors)
median = np.mean(OOS_Resolutions)
maximum = max(Gain)
fig = plt.figure(figsize=(20,10))
plt.errorbar(Gain, OOS_Resolutions, yerr=OOS_Errors, fmt='^', ecolor='red')
plt.plot([0,maximum], [median, median], '--')
plt.show()
# Out:
# [7.952753132304707, 7.910389214413931, 7.901355606928132, 7.924567944004058, 7.857263642821662, 7.866026145009265, 7.8156651450482455, 7.851481312086195, 7.836547770312591, 7.812129329268235, 7.787632177444091, 7.844902695639555]
# [0.031986804002495664, 0.031725535102547615, 0.034122855529400406, 0.03288955239490434, 0.03580738323600622, 0.031238652428604616, 0.03326265318890095, 0.03264392781252991, 0.03368663041478023, 0.03435525113621333, 0.03483138661858479, 0.03531277523458555]

# %%
#Gain = [5,6,9,12,15,18,21,24,28,32]
Gain= [9,12,15,18,21,24,28,32,36,40,44,48]
Gain = Gain[4:]
print(OOS_Resolutions)
print(OOS_Errors)
median = np.mean(OOS_Resolutions[4:])
maximum = max(Gain[4:])
fig = plt.figure(figsize=(20,10))
plt.errorbar(Gain, OOS_Resolutions[4:], yerr=OOS_Errors[4:], fmt='^', ecolor='red')
plt.plot([0,maximum], [median, median], '--')
plt.show()
# Out:
# [7.952753132304707, 7.910389214413931, 7.901355606928132, 7.924567944004058, 7.857263642821662, 7.866026145009265, 7.8156651450482455, 7.851481312086195, 7.836547770312591, 7.812129329268235, 7.787632177444091, 7.844902695639555]
# [0.031986804002495664, 0.031725535102547615, 0.034122855529400406, 0.03288955239490434, 0.03580738323600622, 0.031238652428604616, 0.03326265318890095, 0.03264392781252991, 0.03368663041478023, 0.03435525113621333, 0.03483138661858479, 0.03531277523458555]

# %%
f = open("/home/giacomo/lab/data/{}/{}25.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 970
inf = 700
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/(2*[2]^2))+ [3]*exp(-[4]*x[0])+ [5]",inf,sup)
fit.SetParameter(0,2200)
fit.SetParameter(1,830)
fit.SetParameter(2,18)
fit.SetParameter(5,80)
#fit.SetParameters(2200,830,18,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)

# %%
f = open("/home/giacomo/lab/data/{}/{}25.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 970
inf = 700
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/(2*[2]^2))+ [3]*exp(-[4]*x[0])+ [5]",inf,sup)
fit.SetParameter(0,2200)
fit.SetParameter(1,830)
fit.SetParameter(2,18)
fit.SetParameter(5,80)
#fit.SetParameters(2200,830,18,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)

# %%
f = open("/home/giacomo/lab/data/{}/{}25.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 970
inf = 700
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/(2*[2]^2))+ [3]*exp(-[4]*x[0])+ [5]",inf,sup)
fit.SetParameter(0,2200)
fit.SetParameter(1,830)
fit.SetParameter(2,18)
fit.SetParameter(5,80)
#fit.SetParameters(2200,830,18,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)

# %%
f = open("/home/giacomo/lab/data/{}/{}25.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 970
inf = 700
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/(2*[2]^2))+ [3]*exp(-[4]*x[0])+ [5]",inf,sup)
fit.SetParameter(0,2200)
fit.SetParameter(1,830)
fit.SetParameter(2,18)
fit.SetParameter(5,80)
#fit.SetParameters(2200,830,18,10,10,100)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)

# %%
#Gain = [5,6,9,12,15,18,21,24,28,32]
Gain= [5,6,9,12,15,18]
print(OOS_Resolutions)
print(OOS_Errors)
median = np.mean(OOS_Resolutions)
maximum = max(Gain)
fig = plt.figure(figsize=(20,10))
plt.errorbar(Gain, OOS_Resolutions, yerr=OOS_Errors, fmt='^', ecolor='red')
plt.plot([0,maximum], [median, median], '--')
plt.show()
# Out:
# [7.9147574768186395, 7.8757015687007605, 7.8029636808958935, 7.818849995560172, 7.732291837794813, 7.710625401649754]
# [0.03186801392347628, 0.03165641195984789, 0.033100656458149386, 0.032835220547580375, 0.03357876962424478, 0.0342555185129212]

# %% [markdown]
# # NEW GAIN

# %%
OOS_Resolutions = []
OOS_Errors = []

# %% [markdown]
# # Seventh spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}20.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 110
inf = 75
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,354,18,0,1)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 92
# integral 140773
#  FCN=460.816 FROM MIGRAD    STATUS=CONVERGED    1590 CALLS        1591 TOTAL
#                      EDM=8.42809e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.45171e+04   5.67938e+01   6.73955e-01   2.47059e-06
#    2  p1           9.12146e+01   1.07628e-02   1.56472e-04  -1.20979e-03
#    3  p2          -4.39988e+00   1.32081e-02   1.43694e-04  -1.63017e-02
#    4  p3          -2.70037e+01   4.97162e-01   7.91360e-04   3.27712e-03
#    5  p4           3.25246e+03   5.01020e+01   7.86761e-02   3.76251e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 8.032045956952565 pm 0.03411406488910454

# %% [markdown]
# # Twelth spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}21.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 140
inf = 80
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,354,18,0,1)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 110
# integral 154151
#  FCN=451.197 FROM MIGRAD    STATUS=CONVERGED    1305 CALLS        1306 TOTAL
#                      EDM=6.69842e-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.7 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1
-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.7 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           3.58212e+03   1.33764e+01   9.37107e-03   3.24894e-06
#    2  p1           3.92327e+02   4.50962e-02  -2.83384e-05  -8.83544e-05
#    3  p2           1.87020e+01   5.57691e-02   3.43943e-05   1.29346e-03
#    4  p3          -1.69018e+00   3.99881e-02   3.48418e-06   7.30451e-03
#    5  p4           8.45673e+02   1.64980e+01  -5.40217e-03   1.87960e-05
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.937514346635699 pm 0.03348867176598719

# %% [markdown]
# # 19 spectrum

# %%
f = open("/home/giacomo/lab/data/{}/{}28.txt".format(data,data), "r")
lists = f.readlines()
value = []
for i in lists:
    value.append(i.strip())
value = list(map(int,value))


sup = 600
inf = 400
bins = sup-inf
peak = value.index(max(value))
print(peak)
h2 = r.TH1F("h2", "h2", bins, inf, sup)
h2.SetFillColor(r.kBlue)
h2.SetFillStyle(3003)
h2.SetLineWidth(2)
i = inf
z = 0
fit = r.TF1("fit", "[0]*exp(-((x[0]-[1])^2)/[2]^2)+[3]*x[0]+[4]",inf,sup)
fit.SetParameters(2200,354,18,0,1)
fit.SetLineWidth(3)
while i < sup:
    h2.SetBinContent(z,value[i])
    i += 1 
    z += 1
integral = 0
for i in value[inf:sup]:
    integral += i
print("integral {}".format(integral))
c2 = r.TCanvas("c2", "c2",50,50,1000,800)
h2.Fit("fit", "RL")
h2.Draw("histo same")
r.gStyle.SetOptStat(1111)
r.gStyle.SetOptFit(1111)
c2.Draw()
# Out:
# 501
# integral 148229
#  FCN=293.677 FROM MIGRAD    STATUS=CONVERGED     351 CALLS         352 TOTAL
#                      EDM=2.44862e-10    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   1.1 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.81424e+03   1.07691e+01  -3.31489e-03  -5.81770e-07
#    2  p1           4.99791e+02   5.61523e-02  -2.72140e-05   3.48052e-04
#    3  p2           2.35466e+01   6.94323e-02   2.10763e-05  -6.38541e-06
#    4  p3          -7.94506e-01   1.56425e-02   1.87320e-05   2.42132e-03
#    5  p4           5.49873e+02   8.40536e+00  -1.14008e-02   3.31710e-06
#                                ERR DEF= 0.5
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2

# %%
fwhm = FWHM(fit)
Res = Resolution(fit)
Err = Res_Error(fit,fwhm)
print("Resolution = {} pm {}".format(Res,Err))
OOS_Resolutions.append(Res)
OOS_Errors.append(Err)
# Out:
# Resolution = 7.844835288227256 pm 0.032728146092533425

# %%
#Gain = [5,6,9,12,15,18,21,24,28,32]
print(len(OOS_Resolutions))
Gain= [5,6,9,12,15,18,21,24]
print(OOS_Resolutions)
print(OOS_Errors)
median = np.mean(OOS_Resolutions)
maximum = max(Gain)
fig = plt.figure(figsize=(20,10))
plt.errorbar(Gain, OOS_Resolutions, yerr=OOS_Errors, fmt='^', ecolor='red')
plt.plot([0,maximum], [median, median], '--')
plt.show()
# Out:
# 8
# [8.032045956952565, 7.964780093693403, 7.952753132304707, 7.91004697383331, 7.881418154315865, 7.8572637437057375, 7.937514346635699, 7.844835288227256]
# [0.03411406488910454, 0.03268315830512017, 0.031986804002495664, 0.03264503664729842, 0.03254161424115445, 0.03605584666199057, 0.03348867176598719, 0.032728146092533425]

# %%
"""
Next step: TGraphErrors with a linear interpolation to see the actual linearity!
"""
# Out:
# '\nNext step: TGraphErrors with a linear interpolation to see the actual linearity!\n'
